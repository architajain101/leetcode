# %% [markdown]
# 3- add total marks column which contains the total marks row wise (each styudent total marks)
# 4- add average column and find the mean of each student marks (row wise)
# 5- print the datset with total marks and avg coloumn ]
# 6- add anew student record
# 7- print the dataset aftyer adding a new
# 8- update the marks in maths to 80
# 9- delete the record of student name mishti
# 10- save updated excel by the name  updated -student execl

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Book1.csv")
df=df.fillna(0)
df
# Out:
#      subject  unit test  maths  science  s.st  hindi  english
# 0      raman          1   22.0     21.0  18.0   20.0     21.0
# 1      raman          2    0.0     20.0  17.0   22.0     24.0
# 2      raman          3   14.0     19.0  15.0   24.0     23.0
# 3    zuharia          1   20.0      0.0  22.0   24.0     19.0
# 4    zuharia          2    0.0     15.0  21.0   25.0      0.0
# 5    zuharia          3   22.0     18.0  19.0    0.0     13.0
# 6   Aashaavy          1   23.0      0.0   0.0   15.0     22.0
# 7   Aashaavy          2    0.0     22.0  24.0   17.0     21.0
# 8   Aashaavy          3   12.0      0.0   0.0    0.0     23.0
# 9     Mishti          1   15.0     22.0  25.0   22.0      0.0
# 10    Mishti          2   18.0     21.0  25.0   24.0     24.0
# 11    Mishti          3   17.0     18.0   0.0   25.0     20.0
